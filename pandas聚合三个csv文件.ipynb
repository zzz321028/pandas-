# %%
import pandas as pd
import numpy as np

ratings = pd.read_csv('ratings.csv',index_col=None)
tags = pd.read_csv('tags.csv',index_col=None)
movies = pd.read_csv('movies.csv',index_col=None)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0     336        1             pixar  1139045764
# 1     474        1             pixar  1137206825
# 2     567        1               fun  1525286013
# 3      62        2           fantasy  1528843929
# 4      62        2  magic board game  1528843932

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies['ratimg_mean'] = ratings.groupby('movieId')['rating'].transform('mean')
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  ratimg_mean
# 0     Adventure|Animation|Children|Comedy|Fantasy     3.920930
# 1                      Adventure|Children|Fantasy     3.259615
# 2                                  Comedy|Romance     3.946078
# ...

# %%
result = pd.merge(movies, tags, on = 'movieId', how = 'left')
result
# Out:
#        movieId                                      title  \
# 0            1                           Toy Story (1995)
# 1            1                           Toy Story (1995)
# 2            1                           Toy Story (1995)
# 3            2                             Jumanji (1995)
# 4            2                             Jumanji (1995)
# ...        ...                                        ...
# 11848   193581  Black Butler: Book of the Atlantic (2017)
# 11849   193583               No Game No Life: Zero (2017)
# 11850   193585                               Flint (2017)
# 11851   193587        Bungo Stray Dogs: Dead Apple (2018)
# 11852   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                             genres  ratimg_mean  userId  \
# 0      Adventure|Animation|Children|Comedy|Fantasy     3.920930   336.0
# 1      Adventure|Animation|Children|Comedy|Fantasy     3.920930   474.0
# ...
